# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd
url='https://raw.githubusercontent.com/GisseYo/ChallengeTelecomX/main/TelecomX_Data.json'
bd_original=pd.read_json(url)
bd_original
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %% [markdown]
# #🔧 Transformación

# %%
colum_customer = pd.json_normalize(bd_original['customer'])
colum_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
colum_phone = pd.json_normalize(bd_original['phone'])
colum_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
colum_internet = pd.json_normalize(bd_original['internet'])
colum_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
colum_account = pd.json_normalize(bd_original['account'])
colum_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
bd_concatenar = pd.concat([bd_original, colum_customer, colum_phone, colum_internet,colum_account], axis=1)
bd_ok = bd_concatenar.drop(['customer','phone','internet','account'], axis=1)
bd_ok
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female              0     Yes        Yes       9
# 1     0003-MKNFE    No    Male              0      No         No       9
# 2     0004-TLHLJ   Yes    Male              0      No         No       4
# 3     0011-IGKFF   Yes    Male              1     Yes         No      13
# 4     0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...   ...     ...            ...     ...        ...     ...
# 7262  9987-LUTYD    No  Female              0      No         No      13
# 7263  9992-RRAMN   Yes    Male              0     Yes         No      22
# 7264  9992-UJOEL    No    Male              0      No         No       2
# 7265  9993-LHIEB    No    Male              0     Yes        Yes      67
# 7266  9995-HOTOH    No    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService  ... OnlineBackup  \
# ...

# %%
bd_ok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
# ...

# %%
bd_analisis = bd_ok[['Churn','SeniorCitizen','Dependents', 'tenure', 'Contract', 'Charges.Monthly', 'Charges.Total']]
bd_analisis
# Out:
#      Churn  SeniorCitizen Dependents  tenure        Contract  Charges.Monthly  \
# 0       No              0        Yes       9        One year            65.60
# 1       No              0         No       9  Month-to-month            59.90
# 2      Yes              0         No       4  Month-to-month            73.90
# 3      Yes              1         No      13  Month-to-month            98.00
# 4      Yes              1         No       3  Month-to-month            83.90
# ...    ...            ...        ...     ...             ...              ...
# 7262    No              0         No      13        One year            55.15
# 7263   Yes              0         No      22  Month-to-month            85.10
# 7264    No              0         No       2  Month-to-month            50.30
# 7265    No              0        Yes      67        Two year            67.85
# 7266    No              0        Yes      63        Two year            59.00
#
#      Charges.Total
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
bd_analisis.isnull().sum()
# Out:
# Churn              0
# SeniorCitizen      0
# Dependents         0
# tenure             0
# Contract           0
# Charges.Monthly    0
# Charges.Total      0
# dtype: int64

# %%
bd_analisis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Churn            7267 non-null   object
#  1   SeniorCitizen    7267 non-null   int64
#  2   Dependents       7267 non-null   object
#  3   tenure           7267 non-null   int64
#  4   Contract         7267 non-null   object
#  5   Charges.Monthly  7267 non-null   float64
#  6   Charges.Total    7267 non-null   object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 397.5+ KB

# %%
bd_analisis['Cuentas_Diarias']= bd_analisis['Charges.Monthly']/30
bd_analisis
# Out:
# <ipython-input-11-1011936611>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd_analisis['Cuentas_Diarias']= bd_analisis['Charges.Monthly']/30
#      Churn  SeniorCitizen Dependents  tenure        Contract  Charges.Monthly  \
# 0       No              0        Yes       9        One year            65.60
# 1       No              0         No       9  Month-to-month            59.90
# 2      Yes              0         No       4  Month-to-month            73.90
# 3      Yes              1         No      13  Month-to-month            98.00
# 4      Yes              1         No       3  Month-to-month            83.90
# ...    ...            ...        ...     ...             ...              ...
# ...

# %%
bd_analisis['Churn']= bd_analisis['Churn'].replace({'Yes': 1, 'No': 0})
bd_analisis
# Out:
# <ipython-input-12-1275060325>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd_analisis['Churn']= bd_analisis['Churn'].replace({'Yes': 1, 'No': 0})
#      Churn  SeniorCitizen Dependents  tenure        Contract  Charges.Monthly  \
# 0        0              0        Yes       9        One year            65.60
# 1        0              0         No       9  Month-to-month            59.90
# 2        1              0         No       4  Month-to-month            73.90
# 3        1              1         No      13  Month-to-month            98.00
# 4        1              1         No       3  Month-to-month            83.90
# ...    ...            ...        ...     ...             ...              ...
# ...

# %%
bd_analisis['Dependents']= bd_analisis['Dependents'].replace({'Yes': 1, 'No': 0})
bd_analisis
# Out:
# <ipython-input-13-3234618994>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   bd_analisis['Dependents']= bd_analisis['Dependents'].replace({'Yes': 1, 'No': 0})
# <ipython-input-13-3234618994>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bd_analisis['Dependents']= bd_analisis['Dependents'].replace({'Yes': 1, 'No': 0})
#      Churn  SeniorCitizen  Dependents  tenure        Contract  \
# 0        0              0           1       9        One year
# ...

# %%
bd_analisis = bd_analisis.rename(columns={'Churn': 'Es_Cliente', 'SeniorCitizen': 'Mayor_Edad', 'Dependents': 'Tiene_Dependientes', 'tenure': 'Meses_Contrato', 'Charges.Monthly': 'Total_Mesual', 'Charges.Total': 'Total_Anual' })
bd_analisis
# Out:
#      Es_Cliente  Mayor_Edad  Tiene_Dependientes  Meses_Contrato  \
# 0             0           0                   1               9
# 1             0           0                   0               9
# 2             1           0                   0               4
# 3             1           1                   0              13
# 4             1           1                   0               3
# ...         ...         ...                 ...             ...
# 7262          0           0                   0              13
# 7263          1           0                   0              22
# 7264          0           0                   0               2
# 7265          0           0                   1              67
# 7266          0           0                   1              63
#
#             Contract  Total_Mesual Total_Anual  Cuentas_Diarias
# 0           One year         65.60       593.3         2.186667
# 1     Month-to-month         59.90       542.4         1.996667
# ...

# %%
bd_clientes = bd_analisis[bd_analisis['Es_Cliente'] == 1]
bd_clientes
# Out:
#      Es_Cliente  Mayor_Edad  Tiene_Dependientes  Meses_Contrato  \
# 2             1           0                   0               4
# 3             1           1                   0              13
# 4             1           1                   0               3
# 18            1           1                   0              45
# 19            1           1                   0               1
# ...         ...         ...                 ...             ...
# 7243          1           1                   0              21
# 7246          1           1                   0               9
# 7260          1           0                   0               1
# 7261          1           0                   0               4
# 7263          1           0                   0              22
#
#             Contract  Total_Mesual Total_Anual  Cuentas_Diarias
# 2     Month-to-month         73.90      280.85         2.463333
# 3     Month-to-month         98.00     1237.85         3.266667
# ...

# %%
bd_retirados = bd_analisis[bd_analisis['Es_Cliente'] == 0]
bd_retirados
# Out:
#      Es_Cliente  Mayor_Edad  Tiene_Dependientes  Meses_Contrato  \
# 0             0           0                   1               9
# 1             0           0                   0               9
# 5             0           0                   1               9
# 6             0           1                   0              71
# 7             0           0                   0              63
# ...         ...         ...                 ...             ...
# 7259          0           0                   0               7
# 7262          0           0                   0              13
# 7264          0           0                   0               2
# 7265          0           0                   1              67
# 7266          0           0                   1              63
#
#             Contract  Total_Mesual Total_Anual  Cuentas_Diarias
# 0           One year         65.60       593.3         2.186667
# 1     Month-to-month         59.90       542.4         1.996667
# ...

# %%
#bd_retirados['Total_Anual'] = bd_retirados['Total_Anual'].replace('',0)
#bd_retirados['Total_Anual'] = bd_retirados['Total_Anual'].astype(float)
#bd_retirados.info()

# %% [markdown]
# #📄Informe final

# %%
mayores_clientes = bd_clientes['Mayor_Edad'].value_counts()[1]
menores_clientes = bd_clientes['Mayor_Edad'].value_counts()[0]
mayores_no_clientes = bd_retirados['Mayor_Edad'].value_counts()[1]
menores_no_clientes = bd_retirados['Mayor_Edad'].value_counts()[0]

conDependiente_clientes = bd_clientes['Tiene_Dependientes'].value_counts()[1]
sinDependiente_clientes = bd_clientes['Tiene_Dependientes'].value_counts()[0]
conDependiente_no_clientes = bd_retirados['Tiene_Dependientes'].value_counts()[1]
sinDependiente_no_clientes = bd_retirados['Tiene_Dependientes'].value_counts()[0]

promMesesContrato_clientes = bd_clientes['Meses_Contrato'].mean()
promMesesContrato_no_clientes = bd_retirados['Meses_Contrato'].mean()

promTotalMesual_clientes = bd_clientes['Total_Mesual'].mean()
promTotalMesual_no_clientes = bd_retirados['Total_Mesual'].mean()

promTotalAnual_clientes = bd_clientes['Total_Anual'].mean()
promTotalAnual_no_clientes = bd_retirados['Total_Anual'].mean()

promCuentasDiarias_clientes = bd_clientes['Cuentas_Diarias'].mean()
promCuentasDiarias_no_clientes = bd_retirados['Cuentas_Diarias'].mean()


#comparativo_mayores = 'comparativo_mayores','mayores_clientes', 'mayores_no_clientes', 'menores_clientes', 'menores_no_clientes'
#comparativo_mayores
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-137716232> in <cell line: 0>()
#      16
#      17 promTotalAnual_clientes = bd_clientes['Total_Anual'].mean()
# ---> 18 promTotalAnual_no_clientes = bd_retirados['Total_Anual'].mean()
#      19
#      20 promCuentasDiarias_clientes = bd_clientes['Cuentas_Diarias'].mean()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in mean(self, axis, skipna, numeric_only, **kwargs)
#    6547         **kwargs,
#    6548     ):
# -> 6549         return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#    6550
#    6551     @doc(make_doc("median", ndim=1))
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   12418         **kwargs,
#   12419     ) -> Series | float:
# > 12420         return self._stat_function(
# ...

# %%
mayores_no_clientes = bd_retirados['Mayor_Edad'].value_counts()
mayores_no_clientes
# Out:
# Mayor_Edad
# 0    4508
# 1     666
# Name: count, dtype: int64
